# %%
# %cd ~/dissertation_code
import pandas as pd
import numpy as np
from functools import reduce
# from sklearn import *
from sklearn.metrics import confusion_matrix
import pysubgroup as ps #test comment
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, r2_score
import sys, itertools
# from rulelist.rulelistmodel.categoricalmodel.categoricalrulelist import CategoricalRuleList
from rulelist import RuleList, SubgroupListCategorical
# from RuleList import SubgroupListCategorical
from rulelist.measures import subgroup_measures

# import categorical_rsd as crsd
# Out:
# /home/tntech.edu/kebrown46/dissertation_code

# %%
def read_data(iteration, model, dataset, n_bins, bin_split="qcut", include_probability=False):
    print("IN read_data")
    train_fn = "input/{0}/uncertainty-info_{1}-train_{2}.csv".format(iteration, model, dataset)
    test_fn = "input/{0}/uncertainty-info_{1}_{2}.csv".format(iteration, model, dataset)

    train_df = pd.read_csv(train_fn, index_col="Unnamed: 0")
    test_df = pd.read_csv(test_fn, index_col="Unnamed: 0")
    #drop truth column
    train_ycls = train_df["truth"]
    test_ycls = test_df["truth"]

    if not include_probability:
        train_df = train_df.drop(["p(positive class)", "truth", "ratio 1 predicted", "rate corrected predicted", "class uncertainty"], axis=1)
        test_df = test_df.drop(["p(positive class)", "truth", "ratio 1 predicted", "rate corrected predicted", "class uncertainty"], axis=1)
    else:
        train_df = train_df.drop(["truth", "ratio 1 predicted", "rate corrected predicted", "class uncertainty"], axis=1)
        test_df = test_df.drop(["truth", "ratio 1 predicted", "rate corrected predicted", "class uncertainty"], axis=1)

    # pysubgroup code for discrete
    train_df = train_df.sort_values(by="uncertainty", ascending=True)
    if bin_split == "cut":
        bins,cps = pd.cut(train_df['uncertainty'], duplicates="drop", bins=n_bins, retbins=True, labels=list(range(n_bins)))
        bins_,cps_ = pd.cut(train_df['uncertainty'], duplicates="drop", bins=n_bins, retbins=True)
    else:
        bins,cps = pd.qcut(train_df['uncertainty'], duplicates="drop", q=n_bins, retbins=True, labels=list(range(n_bins)))
        bins_,cps_ = pd.qcut(train_df['uncertainty'], duplicates="drop", q=n_bins, retbins=True)

    bins.rename("uncertainty group", inplace=True)
    bins_.value_counts().to_csv("RQ 3/results/bins_{dataset}_{model}_{bins}bins.csv".format(dataset=dataset, model=model, bins=n_bins))
    train_df["uncertainty group"] = bins
    #train_df = train_df.sample(frac=1)
    

    test_df["uncertainty group"] = pd.cut(test_df["uncertainty"], right=False, duplicates="drop", bins=cps, labels=False, include_lowest=True)
    # df.loc[df['A'] > 2, 'B'] = new_val

    print(cps)
    print(cps[0])
    print(test_df["uncertainty"] <= cps[0])
    test_df.loc[test_df["uncertainty"] >= cps[-1], "uncertainty group"] = len(cps)-2#.fillna(len(cps)-2, inplace=True)
    test_df.loc[test_df["uncertainty"] <= cps[0], "uncertainty group"] = 0#.fillna(0, inplace=True)


    # test_df.dropna(inplace=True)
    # test_df =  pd.concat([test_df, sub_1, sub_2], axis=0)


    print("!! UQ GROUP VALUES: ", np.unique(test_df["uncertainty group"].values))
    print(test_df.loc[np.isnan(test_df["uncertainty group"])])
    print(test_df[["uncertainty group", "uncertainty"]])
    print(np.unique(test_df["uncertainty group"], return_counts=True))

    train_df = train_df.drop(["uncertainty"], axis=1)
    test_df = test_df.drop(["uncertainty"], axis=1)

    return train_df, test_df, train_ycls, test_ycls

# %%
def _get_validation_curves(n_bins, iteration, model, dataset):
    train_df, test_df, train_ycls, test_ycls = read_data(iteration, 
                                                              model,
                                                              dataset, 
                                                              n_bins, 
                                                              bin_split="qcut", 
                                                              include_probability= False)
    train_df, val_df = train_test_split(train_df, test_size=0.2)
    
    print("In run_sgd")
    print("test_df.shape = ", test_df.shape)
    model_name = model
    features = list(test_df.columns)
    for x in ["uncertainty", "uncertainty group"]:
        while x in features: features.remove(x)

    trainX = train_df[features]
    valX = val_df[features]
    print(list(trainX))
    trainY_cat = train_df["uncertainty group"]
    valY_cat = val_df["uncertainty group"]
    
    testX = test_df[features]
    print(list(testX))
    testY_cat = test_df["uncertainty group"]
    
    
    results = {}
    alphas = [increment/100 for increment in range(0, 100, 5)]
    for alpha in alphas:
        args = {
                # "data": data,
                "max_rules": np.inf,
                "beam_width": 100,
                "min_support": 1,
                "beam_width": 1,
                "max_depth": 5, 
                "alpha_gain": alpha,
        }

        print(args)
        model = SubgroupListCategorical(**args)
        # SubgroupListCategorical(**args)
        model.fit(trainX, trainY_cat)
        print(model)
        pred = model.predict(testX)
        true = testY_cat.values.astype(int)
        pred = pred.astype(int)

        accuracy = accuracy_score(true, pred)
        no_rules = model.number_rules
        results[alpha] = {
            "alpha": alpha,
            "Validation Fidelity": accuracy,
            "No. Subgroups": no_rules
        }
    return results
        
def get_validation_curves(n_bins, model, dataset, res_key):
    
    for i in range(0,10):
        results = _get_validation_curves(n_bins=2, iteration=0, model=model, dataset=dataset)
        res_df = pd.DataFrame(results).transpose()
        res_df.to_csv(f"RQ 3/results/{res_key}/RSDTuning_{model}_{dataset}_{i}_bins{n_bins}.csv")

# %%
n_bins_list = [2,3]
model_list = ["NN-dropout", "catboost-ve"]
datasets = ["trauma_uk", "critical_outcome", "ED_3day_readmit", "hospitalization_prediction", "diabetes",]
eval_combos = itertools.product(n_bins_list, model_list, datasets)
for n, m, d in eval_combos:
    print(n,m,d)
    res = get_validation_curves(n_bins=n, model=m, dataset=d, res_key="dissertation_SG")
# Out:
# 2 NN-dropout trauma_uk
# IN read_data
# [0.00074678 0.04454555 0.2501911 ]
# 0.00074677815
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5684    False
# 5685    False
# 5686    False
# 5687    False
# 5688    False
# Name: uncertainty, Length: 5689, dtype: bool
# !! UQ GROUP VALUES:  [0 1]
# Empty DataFrame
# Columns: [uncertainty, TRAUMATYPE, SYSBP, RR, GCS, EDMOTOR, SI, SIRANK, AGE, SEX, RTS, FlailAMPT, SCIAMPT, RRAMPT, GCSAMPT, ABDAMPT, ARMAMPT, CHESTAMPT, FACEAMPT, HEADAMPT, LEGAMPT, NECKAMPT, MultisystemAMPT, AnatomicalAMPT, PhysiologicalAMPT, LungAMPT, AMPT, Mechanism, RTSCode, AgeGroups, SBPCode, MotorCode, AMPT2, uncertainty group]
# Index: []
#
# [0 rows x 34 columns]
#       uncertainty group  uncertainty
# 0                     0     0.014881
# 1                     0     0.032195
# 2                     0     0.021461
# 3                     1     0.044716
# 4                     0     0.011303
# ...                 ...          ...
# 5684                  1     0.052608
# 5685                  1     0.099619
# 5686                  0     0.042655
# 5687                  0     0.012950
# 5688                  1     0.108136
#
# [5689 rows x 2 columns]
# (array([0, 1]), array([2837, 2852]))
# In run_sgd
# test_df.shape =  (5689, 33)
# ['TRAUMATYPE', 'SYSBP', 'RR', 'GCS', 'EDMOTOR', 'SI', 'SIRANK', 'AGE', 'SEX', 'RTS', 'FlailAMPT', 'SCIAMPT', 'RRAMPT', 'GCSAMPT', 'ABDAMPT', 'ARMAMPT', 'CHESTAMPT', 'FACEAMPT', 'HEADAMPT', 'LEGAMPT', 'NECKAMPT', 'MultisystemAMPT', 'AnatomicalAMPT', 'PhysiologicalAMPT', 'LungAMPT', 'AMPT', 'Mechanism', 'RTSCode', 'AgeGroups', 'SBPCode', 'MotorCode', 'AMPT2']
# ['TRAUMATYPE', 'SYSBP', 'RR', 'GCS', 'EDMOTOR', 'SI', 'SIRANK', 'AGE', 'SEX', 'RTS', 'FlailAMPT', 'SCIAMPT', 'RRAMPT', 'GCSAMPT', 'ABDAMPT', 'ARMAMPT', 'CHESTAMPT', 'FACEAMPT', 'HEADAMPT', 'LEGAMPT', 'NECKAMPT', 'MultisystemAMPT', 'AnatomicalAMPT', 'PhysiologicalAMPT', 'LungAMPT', 'AMPT', 'Mechanism', 'RTSCode', 'AgeGroups', 'SBPCode', 'MotorCode', 'AMPT2']
# {'max_rules': inf, 'beam_width': 1, 'min_support': 1, 'max_depth': 5, 'alpha_gain': 0.1}
# /home/tntech.edu/kebrown46/RuleList/rulelist/datastructure/data.py:80: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for name, values in self.input_data.iteritems():
# /home/tntech.edu/kebrown46/RuleList/rulelist/rulelistmodel/categoricalmodel/categoricaltarget.py:40: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self.categories = {colname: colvals.unique() for colname, colvals in target_values.iteritems()} #ignores NANs values
# /home/tntech.edu/kebrown46/RuleList/rulelist/rulelistmodel/categoricalmodel/categoricaltarget.py:54: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for namecol, colvals in target_values.iteritems():
# Iteration: 1
# Iteration: 2
# Iteration: 3
# Iteration: 4
# Iteration: 5
# Iteration: 6
# Iteration: 7
# Iteration: 8
# Iteration: 9
# Iteration: 10
# Iteration: 11
# Iteration: 12
# Iteration: 13
# Iteration: 14
# If AMPT >= 1.0  THEN  usage = 16848 : target = uncertainty groupPr(0) = 0.13912630579297247;Pr(1) = 0.8608736942070275;
# ELSE IF 0.0 <= ABDAMPT < 1.0  AND  0.0 <= HEADAMPT < 1.0  AND  0.0 <= CHESTAMPT < 1.0  AND  RTS >= 7.1082  THEN  usage = 12603 : target = uncertainty groupPr(0) = 0.9632627152265334;Pr(1) = 0.03673728477346663;
# ELSE IF AGE >= 61.0  AND  Mechanism >= 1.0  AND  HEADAMPT >= 1.0  AND  0.0 <= ABDAMPT < 1.0  THEN  usage = 700 : target = uncertainty groupPr(0) = 0.018571428571428572;Pr(1) = 0.9814285714285714;
# ELSE IF HEADAMPT >= 1.0  AND  0.0 <= LEGAMPT < 1.0  AND  AgeGroups < 5.0  AND  0.0 <= ARMAMPT < 1.0  AND  SI < 0.9219304079999999  THEN  usage = 3248 : target = uncertainty groupPr(0) = 0.75;Pr(1) = 0.25;
# ELSE IF Mechanism >= 1.0  AND  AGE >= 36.0  AND  RTS >= 7.1082  THEN  usage = 1533 : target = uncertainty groupPr(0) = 0.29549902152641877;Pr(1) = 0.7045009784735812;
# ELSE IF 0.525316456 <= SI < 0.776978417  AND  0.0 <= LEGAMPT < 1.0  AND  0.0 <= Mechanism < 1.0  THEN  usage = 1805 : target = uncertainty groupPr(0) = 0.6487534626038781;Pr(1) = 0.3512465373961219;
# ELSE IF SYSBP >= 156.0  AND  0.0 <= SEX < 1.0  THEN  usage = 452 : target = uncertainty groupPr(0) = 0.29867256637168144;Pr(1) = 0.7013274336283186;
# ELSE IF RR >= 24.0  AND  LEGAMPT >= 1.0  THEN  usage = 223 : target = uncertainty groupPr(0) = 0.23318385650224216;Pr(1) = 0.7668161434977578;
# ELSE IF 0.0 <= CHESTAMPT < 1.0  AND  112.0 <= SYSBP < 134.0  AND  0.0 <= LEGAMPT < 1.0  AND  0.0 <= ARMAMPT < 1.0  THEN  usage = 587 : target = uncertainty groupPr(0) = 0.6473594548551959;Pr(1) = 0.3526405451448041;
# ELSE IF ABDAMPT >= 1.0  AND  SI >= 0.9219304079999999  AND  0.0 <= HEADAMPT < 1.0  THEN  usage = 248 : target = uncertainty groupPr(0) = 0.2217741935483871;Pr(1) = 0.7782258064516129;
# ELSE IF RR < 20.0  AND  0.0 <= ABDAMPT < 1.0  AND  AGE < 61.0  THEN  usage = 781 : target = uncertainty groupPr(0) = 0.6261203585147247;Pr(1) = 0.3738796414852753;
# ELSE IF CHESTAMPT >= 1.0  AND  SI >= 0.9219304079999999  THEN  usage = 107 : target = uncertainty groupPr(0) = 0.14018691588785046;Pr(1) = 0.8598130841121495;
# ELSE IF LEGAMPT >= 1.0  AND  0.0 <= SEX < 1.0  AND  0.0 <= RTSCode < 1.0  THEN  usage = 319 : target = uncertainty groupPr(0) = 0.329153605015674;Pr(1) = 0.670846394984326;
#  ELSE  usage = 1505 : target = uncertainty groupPr(0) = 0.5022583559168925;Pr(1) = 0.4977416440831075;
# {'max_rules': inf, 'beam_width': 1, 'min_support': 1, 'max_depth': 5, 'alpha_gain': 0.2}
# /home/tntech.edu/kebrown46/RuleList/rulelist/datastructure/data.py:80: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for name, values in self.input_data.iteritems():
# /home/tntech.edu/kebrown46/RuleList/rulelist/rulelistmodel/categoricalmodel/categoricaltarget.py:40: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self.categories = {colname: colvals.unique() for colname, colvals in target_values.iteritems()} #ignores NANs values
# /home/tntech.edu/kebrown46/RuleList/rulelist/rulelistmodel/categoricalmodel/categoricaltarget.py:54: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for namecol, colvals in target_values.iteritems():
# Iteration: 1
# Iteration: 2
# Iteration: 3
# Iteration: 4
# Iteration: 5
# Iteration: 6
# Iteration: 7
# Iteration: 8
# Iteration: 9
# Iteration: 10
# Iteration: 11
# Iteration: 12
# Iteration: 13
# Iteration: 14
# Iteration: 15
# Iteration: 16
# Iteration: 17
# Iteration: 18
# If AMPT >= 1.0  THEN  usage = 16848 : target = uncertainty groupPr(0) = 0.13912630579297247;Pr(1) = 0.8608736942070275;
# ELSE IF 0.0 <= ABDAMPT < 1.0  AND  0.0 <= HEADAMPT < 1.0  AND  0.0 <= CHESTAMPT < 1.0  AND  RTS >= 7.1082  THEN  usage = 12603 : target = uncertainty groupPr(0) = 0.9632627152265334;Pr(1) = 0.03673728477346663;
# ELSE IF AGE >= 61.0  AND  Mechanism >= 1.0  AND  HEADAMPT >= 1.0  AND  0.0 <= ABDAMPT < 1.0  THEN  usage = 700 : target = uncertainty groupPr(0) = 0.018571428571428572;Pr(1) = 0.9814285714285714;
# ELSE IF HEADAMPT >= 1.0  AND  0.0 <= LEGAMPT < 1.0  AND  AgeGroups < 5.0  AND  0.0 <= Mechanism < 1.0  AND  0.0 <= SEX < 1.0  THEN  usage = 1744 : target = uncertainty groupPr(0) = 0.8245412844036697;Pr(1) = 0.17545871559633028;
# ELSE IF SIRANK < 1.0  AND  Mechanism >= 1.0  AND  AGE >= 26.0  THEN  usage = 425 : target = uncertainty groupPr(0) = 0.16470588235294117;Pr(1) = 0.8352941176470589;
# ELSE IF HEADAMPT >= 1.0  AND  AGE < 47.0  AND  0.0 <= LEGAMPT < 1.0  AND  0.0 <= CHESTAMPT < 1.0  AND  0.0 <= RTSCode < 1.0  THEN  usage = 1882 : target = uncertainty groupPr(0) = 0.6817215727948991;Pr(1) = 0.31827842720510097;
# ELSE IF SI >= 0.9219304079999999  AND  CHESTAMPT >= 1.0  THEN  usage = 263 : target = uncertainty groupPr(0) = 0.1482889733840304;Pr(1) = 0.8517110266159695;
# ELSE IF LEGAMPT >= 1.0  AND  AGE >= 61.0  AND  RTS >= 7.1082  THEN  usage = 205 : target = uncertainty groupPr(0) = 0.12682926829268293;Pr(1) = 0.8731707317073171;
# ELSE IF SEX >= 1.0  AND  SI < 0.776978417  AND  0.0 <= Mechanism < 1.0  AND  SYSBP < 156.0  AND  AGE >= 26.0  THEN  usage = 723 : target = uncertainty groupPr(0) = 0.7164591977869986;Pr(1) = 0.2835408022130014;
# ELSE IF Mechanism >= 1.0  AND  SIRANK < 2.0  AND  AGE >= 36.0  AND  0.0 <= SEX < 1.0  AND  0.0 <= ARMAMPT < 1.0  THEN  usage = 533 : target = uncertainty groupPr(0) = 0.25140712945590993;Pr(1) = 0.7485928705440901;
# ELSE IF SIRANK < 1.0  AND  0.0 <= SEX < 1.0  AND  SYSBP >= 143.0  AND  0.0 <= LEGAMPT < 1.0  THEN  usage = 274 : target = uncertainty groupPr(0) = 0.2664233576642336;Pr(1) = 0.7335766423357665;
# ELSE IF RR < 20.0  AND  0.0 <= ABDAMPT < 1.0  AND  GCS >= 15.0  THEN  usage = 1082 : target = uncertainty groupPr(0) = 0.6377079482439926;Pr(1) = 0.36229205175600737;
# ELSE IF LEGAMPT >= 1.0  AND  0.0 <= SEX < 1.0  AND  RTS >= 7.1082  AND  RR >= 18.0  THEN  usage = 478 : target = uncertainty groupPr(0) = 0.23640167364016737;Pr(1) = 0.7635983263598326;
# ELSE IF 0.0 <= CHESTAMPT < 1.0  AND  0.525316456 <= SI < 0.9219304079999999  AND  0.0 <= Mechanism < 1.0  AND  0.0 <= ARMAMPT < 1.0  AND  0.0 <= LEGAMPT < 1.0  THEN  usage = 727 : target = uncertainty groupPr(0) = 0.6891334250343879;Pr(1) = 0.3108665749656121;
# ELSE IF SYSBP < 112.0  THEN  usage = 461 : target = uncertainty groupPr(0) = 0.37310195227765725;Pr(1) = 0.6268980477223427;
# ELSE IF 0.0 <= ABDAMPT < 1.0  AND  0.0 <= SEX < 1.0  AND  0.0 <= ARMAMPT < 1.0  THEN  usage = 374 : target = uncertainty groupPr(0) = 0.6577540106951871;Pr(1) = 0.3422459893048128;
# ELSE IF CHESTAMPT >= 1.0  AND  AGE < 26.0  THEN  usage = 159 : target = uncertainty groupPr(0) = 0.1949685534591195;Pr(1) = 0.8050314465408805;
#  ELSE  usage = 1478 : target = uncertainty groupPr(0) = 0.5022583559168925;Pr(1) = 0.4977416440831075;
# {'max_rules': inf, 'beam_width': 1, 'min_support': 1, 'max_depth': 5, 'alpha_gain': 0.3}
# /home/tntech.edu/kebrown46/RuleList/rulelist/datastructure/data.py:80: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for name, values in self.input_data.iteritems():
# /home/tntech.edu/kebrown46/RuleList/rulelist/rulelistmodel/categoricalmodel/categoricaltarget.py:40: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self.categories = {colname: colvals.unique() for colname, colvals in target_values.iteritems()} #ignores NANs values
# /home/tntech.edu/kebrown46/RuleList/rulelist/rulelistmodel/categoricalmodel/categoricaltarget.py:54: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for namecol, colvals in target_values.iteritems():
# Iteration: 1
# Iteration: 2
# Iteration: 3
# Iteration: 4
# Iteration: 5
# Iteration: 6
# Iteration: 7
# Iteration: 8
# Iteration: 9
# Iteration: 10
# Iteration: 11
# Iteration: 12
# Iteration: 13
# Iteration: 14
# Iteration: 15
# Iteration: 16
# Iteration: 17
# Iteration: 18
# Iteration: 19
# If AMPT >= 1.0  THEN  usage = 16848 : target = uncertainty groupPr(0) = 0.13912630579297247;Pr(1) = 0.8608736942070275;
# ELSE IF 0.0 <= HEADAMPT < 1.0  AND  0.0 <= ABDAMPT < 1.0  AND  0.0 <= CHESTAMPT < 1.0  AND  0.0 <= RTSCode < 1.0  THEN  usage = 12523 : target = uncertainty groupPr(0) = 0.9639862652718997;Pr(1) = 0.036013734728100294;
# ELSE IF AGE >= 61.0  AND  Mechanism >= 1.0  AND  HEADAMPT >= 1.0  AND  0.0 <= ABDAMPT < 1.0  THEN  usage = 700 : target = uncertainty groupPr(0) = 0.018571428571428572;Pr(1) = 0.9814285714285714;
# ELSE IF HEADAMPT >= 1.0  AND  AGE < 47.0  AND  0.0 <= LEGAMPT < 1.0  AND  0.0 <= SEX < 1.0  AND  0.0 <= ARMAMPT < 1.0  THEN  usage = 2329 : target = uncertainty groupPr(0) = 0.7908973808501503;Pr(1) = 0.20910261914984973;
# ELSE IF SIRANK < 1.0  AND  Mechanism >= 1.0  THEN  usage = 430 : target = uncertainty groupPr(0) = 0.1744186046511628;Pr(1) = 0.8255813953488372;
# ELSE IF SEX >= 1.0  AND  0.0 <= CHESTAMPT < 1.0  AND  AgeGroups < 5.0  AND  SI < 0.9219304079999999  AND  0.0 <= Mechanism < 1.0  THEN  usage = 1228 : target = uncertainty groupPr(0) = 0.7109120521172638;Pr(1) = 0.2890879478827362;
# ELSE IF LEGAMPT >= 1.0  AND  RR >= 20.0  AND  0.0 <= RTSCode < 1.0  AND  AgeGroups >= 4.0  AND  0.0 <= CHESTAMPT < 1.0  THEN  usage = 411 : target = uncertainty groupPr(0) = 0.1630170316301703;Pr(1) = 0.8369829683698297;
# ELSE IF SI >= 0.9219304079999999  AND  CHESTAMPT >= 1.0  THEN  usage = 259 : target = uncertainty groupPr(0) = 0.138996138996139;Pr(1) = 0.861003861003861;
# ELSE IF 0.0 <= Mechanism < 1.0  AND  36.0 <= AGE < 61.0  AND  0.0 <= ABDAMPT < 1.0  AND  SI < 0.776978417  AND  SYSBP < 156.0  THEN  usage = 532 : target = uncertainty groupPr(0) = 0.7913533834586466;Pr(1) = 0.20864661654135339;
# ELSE IF SIRANK < 1.0  AND  0.0 <= SEX < 1.0  AND  0.0 <= HEADAMPT < 1.0  THEN  usage = 243 : target = uncertainty groupPr(0) = 0.27983539094650206;Pr(1) = 0.720164609053498;
# ELSE IF LEGAMPT >= 1.0  AND  AGE >= 47.0  AND  0.0 <= RTSCode < 1.0  AND  Mechanism >= 1.0  THEN  usage = 126 : target = uncertainty groupPr(0) = 0.1111111111111111;Pr(1) = 0.8888888888888888;
# ELSE IF 0.0 <= Mechanism < 1.0  AND  0.0 <= LEGAMPT < 1.0  AND  AGE >= 36.0  AND  112.0 <= SYSBP < 156.0  AND  0.0 <= ARMAMPT < 1.0  THEN  usage = 683 : target = uncertainty groupPr(0) = 0.6764275256222547;Pr(1) = 0.3235724743777452;
# ELSE IF 13.0 <= GCS < 15.0  THEN  usage = 479 : target = uncertainty groupPr(0) = 0.3987473903966597;Pr(1) = 0.6012526096033403;
# ELSE IF ABDAMPT >= 1.0  AND  CHESTAMPT >= 1.0  THEN  usage = 331 : target = uncertainty groupPr(0) = 0.2598187311178248;Pr(1) = 0.7401812688821753;
# ELSE IF AGE < 36.0  AND  0.0 <= LEGAMPT < 1.0  AND  0.525316456 <= SI < 0.9219304079999999  AND  0.0 <= SEX < 1.0  THEN  usage = 949 : target = uncertainty groupPr(0) = 0.6238145416227608;Pr(1) = 0.3761854583772392;
# ELSE IF ABDAMPT >= 1.0  AND  RTS < 7.8408  THEN  usage = 58 : target = uncertainty groupPr(0) = 0.1206896551724138;Pr(1) = 0.8793103448275862;
# ELSE IF 7.1082 <= RTS < 7.8408  AND  0.0 <= HEADAMPT < 1.0  THEN  usage = 64 : target = uncertainty groupPr(0) = 0.828125;Pr(1) = 0.171875;
# ELSE IF 0.0 <= SEX < 1.0  AND  Mechanism >= 1.0  AND  1.0 <= SIRANK < 2.0  AND  0.0 <= LEGAMPT < 1.0  AND  0.0 <= CHESTAMPT < 1.0  THEN  usage = 238 : target = uncertainty groupPr(0) = 0.23949579831932774;Pr(1) = 0.7605042016806722;
#  ELSE  usage = 2528 : target = uncertainty groupPr(0) = 0.5022583559168925;Pr(1) = 0.4977416440831075;
# {'max_rules': inf, 'beam_width': 1, 'min_support': 1, 'max_depth': 5, 'alpha_gain': 0.4}
# /home/tntech.edu/kebrown46/RuleList/rulelist/datastructure/data.py:80: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for name, values in self.input_data.iteritems():
# /home/tntech.edu/kebrown46/RuleList/rulelist/rulelistmodel/categoricalmodel/categoricaltarget.py:40: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self.categories = {colname: colvals.unique() for colname, colvals in target_values.iteritems()} #ignores NANs values
# /home/tntech.edu/kebrown46/RuleList/rulelist/rulelistmodel/categoricalmodel/categoricaltarget.py:54: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for namecol, colvals in target_values.iteritems():
# Iteration: 1
# Iteration: 2
# Iteration: 3
# Iteration: 4
# Iteration: 5
# Iteration: 6
# Iteration: 7
# Iteration: 8
# Iteration: 9
# Iteration: 10
# Iteration: 11
# Iteration: 12
# Iteration: 13
# Iteration: 14
# Iteration: 15
# Iteration: 16
# Iteration: 17
# Iteration: 18
# Iteration: 19
# Iteration: 20
# Iteration: 21
# Iteration: 22
# Iteration: 23
# Iteration: 24
# Iteration: 25
# Iteration: 26
# Iteration: 27
# Iteration: 28
# If AMPT >= 1.0  AND  0.0 <= PhysiologicalAMPT < 1.0  AND  MultisystemAMPT >= 1.0  THEN  usage = 6423 : target = uncertainty groupPr(0) = 0.027245835279464423;Pr(1) = 0.9727541647205356;
# ELSE IF 0.0 <= AMPT < 1.0  AND  0.0 <= HEADAMPT < 1.0  AND  0.0 <= ABDAMPT < 1.0  AND  0.0 <= CHESTAMPT < 1.0  AND  0.0 <= RTSCode < 1.0  THEN  usage = 12523 : target = uncertainty groupPr(0) = 0.9639862652718997;Pr(1) = 0.036013734728100294;
# ELSE IF AMPT2 >= 1.0  AND  0.0 <= MultisystemAMPT < 1.0  THEN  usage = 3249 : target = uncertainty groupPr(0) = 0.009541397353031703;Pr(1) = 0.9904586026469683;
# ELSE IF AnatomicalAMPT >= 1.0  AND  0.0 <= ABDAMPT < 1.0  THEN  usage = 2945 : target = uncertainty groupPr(0) = 0.16536502546689305;Pr(1) = 0.834634974533107;
# ELSE IF AGE >= 61.0  AND  Mechanism >= 1.0  AND  HEADAMPT >= 1.0  AND  0.0 <= ABDAMPT < 1.0  THEN  usage = 878 : target = uncertainty groupPr(0) = 0.014806378132118452;Pr(1) = 0.9851936218678815;
# ELSE IF 1.0 <= AMPT < 2.0  AND  0.0 <= PhysiologicalAMPT < 1.0  THEN  usage = 277 : target = uncertainty groupPr(0) = 0.0036101083032490976;Pr(1) = 0.9963898916967509;
# ELSE IF 0.0 <= Mechanism < 1.0  AND  0.525316456 <= SI < 0.776978417  AND  0.0 <= PhysiologicalAMPT < 1.0  AND  0.0 <= LEGAMPT < 1.0  AND  HEADAMPT >= 1.0  THEN  usage = 1732 : target = uncertainty groupPr(0) = 0.7794457274826789;Pr(1) = 0.22055427251732102;
# ELSE IF SIRANK < 1.0  AND  Mechanism >= 1.0  AND  AGE >= 36.0  AND  RR >= 14.0  THEN  usage = 382 : target = uncertainty groupPr(0) = 0.13089005235602094;Pr(1) = 0.8691099476439791;
# ELSE IF AGE >= 61.0  AND  SYSBP >= 156.0  THEN  usage = 489 : target = uncertainty groupPr(0) = 0.310838445807771;Pr(1) = 0.689161554192229;
# ELSE IF 0.0 <= ABDAMPT < 1.0  AND  EDMOTOR < 6.0  AND  Mechanism >= 1.0  AND  HEADAMPT >= 1.0  AND  AgeGroups >= 4.0  THEN  usage = 137 : target = uncertainty groupPr(0) = 0.029197080291970802;Pr(1) = 0.9708029197080292;
# ELSE IF 0.0 <= ABDAMPT < 1.0  AND  GCS >= 15.0  AND  0.0 <= CHESTAMPT < 1.0  AND  0.0 <= HEADAMPT < 1.0  AND  7.1082 <= RTS < 7.8408  THEN  usage = 375 : target = uncertainty groupPr(0) = 0.936;Pr(1) = 0.064;
# ELSE IF 7.1082 <= RTS < 7.8408  AND  ABDAMPT >= 1.0  AND  0.0 <= GCSAMPT < 1.0  THEN  usage = 499 : target = uncertainty groupPr(0) = 0.20240480961923848;Pr(1) = 0.7975951903807615;
# ELSE IF 1.0 <= AMPT < 2.0  AND  HEADAMPT >= 1.0  AND  Mechanism >= 1.0  THEN  usage = 285 : target = uncertainty groupPr(0) = 0.17192982456140352;Pr(1) = 0.8280701754385965;
# ELSE IF HEADAMPT >= 1.0  AND  0.0 <= PhysiologicalAMPT < 1.0  AND  0.0 <= LEGAMPT < 1.0  AND  AGE < 47.0  AND  SI < 0.9219304079999999  THEN  usage = 1805 : target = uncertainty groupPr(0) = 0.7285318559556787;Pr(1) = 0.27146814404432135;
# ELSE IF Mechanism >= 1.0  AND  SIRANK < 2.0  AND  AGE >= 36.0  AND  0.0 <= SEX < 1.0  AND  0.0 <= ARMAMPT < 1.0  THEN  usage = 598 : target = uncertainty groupPr(0) = 0.23745819397993312;Pr(1) = 0.7625418060200669;
# ELSE IF RR >= 24.0  AND  LEGAMPT >= 1.0  AND  0.0 <= MultisystemAMPT < 1.0  AND  AgeGroups >= 4.0  THEN  usage = 272 : target = uncertainty groupPr(0) = 0.1801470588235294;Pr(1) = 0.8198529411764706;
# ELSE IF RR < 20.0  AND  ARMAMPT >= 1.0  AND  EDMOTOR < 6.0  AND  CHESTAMPT >= 1.0  AND  HEADAMPT >= 1.0  THEN  usage = 281 : target = uncertainty groupPr(0) = 0.8932384341637011;Pr(1) = 0.10676156583629894;
# ELSE IF GCSAMPT >= 1.0  AND  0.0 <= LEGAMPT < 1.0  AND  ABDAMPT >= 1.0  AND  0.0 <= CHESTAMPT < 1.0  THEN  usage = 138 : target = uncertainty groupPr(0) = 0.12318840579710146;Pr(1) = 0.8768115942028986;
# ELSE IF 0.525316456 <= SI < 0.776978417  AND  GCS >= 15.0  AND  0.0 <= Mechanism < 1.0  AND  SYSBP < 156.0  AND  26.0 <= AGE < 61.0  THEN  usage = 879 : target = uncertainty groupPr(0) = 0.6871444823663254;Pr(1) = 0.31285551763367464;
# ELSE IF CHESTAMPT >= 1.0  AND  0.0 <= HEADAMPT < 1.0  AND  SI >= 0.9219304079999999  AND  GCS >= 13.0  THEN  usage = 297 : target = uncertainty groupPr(0) = 0.16498316498316498;Pr(1) = 0.835016835016835;
# ELSE IF 0.0 <= ABDAMPT < 1.0  AND  GCS >= 15.0  AND  RR < 20.0  THEN  usage = 1124 : target = uncertainty groupPr(0) = 0.6290035587188612;Pr(1) = 0.3709964412811388;
# ELSE IF SIRANK < 1.0  AND  0.0 <= SEX < 1.0  THEN  usage = 338 : target = uncertainty groupPr(0) = 0.3106508875739645;Pr(1) = 0.6893491124260355;
# ELSE IF LEGAMPT >= 1.0  AND  0.0 <= CHESTAMPT < 1.0  AND  ABDAMPT >= 1.0  THEN  usage = 422 : target = uncertainty groupPr(0) = 0.24881516587677724;Pr(1) = 0.7511848341232228;
# ELSE IF 0.0 <= CHESTAMPT < 1.0  AND  0.0 <= HEADAMPT < 1.0  AND  112.0 <= SYSBP < 156.0  THEN  usage = 1106 : target = uncertainty groupPr(0) = 0.6347197106690777;Pr(1) = 0.36528028933092227;
# ELSE IF 0.0 <= HEADAMPT < 1.0  AND  ABDAMPT >= 1.0  AND  CHESTAMPT >= 1.0  AND  0.0 <= ARMAMPT < 1.0  THEN  usage = 396 : target = uncertainty groupPr(0) = 0.28535353535353536;Pr(1) = 0.7146464646464646;
# ELSE IF MultisystemAMPT >= 1.0  AND  LEGAMPT >= 1.0  AND  EDMOTOR < 6.0  AND  HEADAMPT >= 1.0  THEN  usage = 193 : target = uncertainty groupPr(0) = 0.9067357512953368;Pr(1) = 0.09326424870466321;
# ELSE IF GCSAMPT >= 1.0  AND  0.0 <= ARMAMPT < 1.0  THEN  usage = 687 : target = uncertainty groupPr(0) = 0.39446870451237265;Pr(1) = 0.6055312954876274;
#  ELSE  usage = 2229 : target = uncertainty groupPr(0) = 0.5022583559168925;Pr(1) = 0.4977416440831075;
# {'max_rules': inf, 'beam_width': 1, 'min_support': 1, 'max_depth': 5, 'alpha_gain': 0.5}
# /home/tntech.edu/kebrown46/RuleList/rulelist/datastructure/data.py:80: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for name, values in self.input_data.iteritems():
# /home/tntech.edu/kebrown46/RuleList/rulelist/rulelistmodel/categoricalmodel/categoricaltarget.py:40: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self.categories = {colname: colvals.unique() for colname, colvals in target_values.iteritems()} #ignores NANs values
# /home/tntech.edu/kebrown46/RuleList/rulelist/rulelistmodel/categoricalmodel/categoricaltarget.py:54: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for namecol, colvals in target_values.iteritems():
# Iteration: 1
# Iteration: 2
# Iteration: 3
# Iteration: 4
# Iteration: 5
# Iteration: 6
# Iteration: 7
# Iteration: 8
# Iteration: 9
# Iteration: 10
# Iteration: 11
# Iteration: 12
# Iteration: 13
# Iteration: 14
# Iteration: 15
# Iteration: 16
# Iteration: 17
# Iteration: 18
# Iteration: 19
# Iteration: 20
# Iteration: 21
# Iteration: 22
# Iteration: 23
# Iteration: 24
# Iteration: 25
# Iteration: 26
# If AMPT >= 1.0  AND  0.0 <= PhysiologicalAMPT < 1.0  AND  MultisystemAMPT >= 1.0  THEN  usage = 6423 : target = uncertainty groupPr(0) = 0.027245835279464423;Pr(1) = 0.9727541647205356;
# ELSE IF AMPT2 >= 1.0  AND  0.0 <= MultisystemAMPT < 1.0  THEN  usage = 3249 : target = uncertainty groupPr(0) = 0.009541397353031703;Pr(1) = 0.9904586026469683;
# ELSE IF 0.0 <= AMPT < 1.0  AND  0.0 <= HEADAMPT < 1.0  AND  0.0 <= ABDAMPT < 1.0  AND  0.0 <= CHESTAMPT < 1.0  AND  0.0 <= RTSCode < 1.0  THEN  usage = 12523 : target = uncertainty groupPr(0) = 0.9639862652718997;Pr(1) = 0.036013734728100294;
# ELSE IF AnatomicalAMPT >= 1.0  AND  0.0 <= ABDAMPT < 1.0  THEN  usage = 2945 : target = uncertainty groupPr(0) = 0.16536502546689305;Pr(1) = 0.834634974533107;
# ELSE IF AGE >= 61.0  AND  Mechanism >= 1.0  AND  HEADAMPT >= 1.0  AND  0.0 <= ABDAMPT < 1.0  THEN  usage = 878 : target = uncertainty groupPr(0) = 0.014806378132118452;Pr(1) = 0.9851936218678815;
# ELSE IF 1.0 <= AMPT < 2.0  AND  0.0 <= PhysiologicalAMPT < 1.0  THEN  usage = 277 : target = uncertainty groupPr(0) = 0.0036101083032490976;Pr(1) = 0.9963898916967509;
# ELSE IF 0.0 <= Mechanism < 1.0  AND  0.525316456 <= SI < 0.776978417  AND  0.0 <= PhysiologicalAMPT < 1.0  AND  0.0 <= LEGAMPT < 1.0  AND  HEADAMPT >= 1.0  THEN  usage = 1732 : target = uncertainty groupPr(0) = 0.7794457274826789;Pr(1) = 0.22055427251732102;
# ELSE IF SIRANK < 1.0  AND  Mechanism >= 1.0  AND  AGE >= 36.0  AND  0.0 <= RTSCode < 1.0  THEN  usage = 360 : target = uncertainty groupPr(0) = 0.12777777777777777;Pr(1) = 0.8722222222222222;
# ELSE IF AGE >= 61.0  AND  SYSBP >= 156.0  THEN  usage = 486 : target = uncertainty groupPr(0) = 0.3065843621399177;Pr(1) = 0.6934156378600823;
# ELSE IF 1.0 <= AMPT < 2.0  AND  HEADAMPT >= 1.0  AND  Mechanism >= 1.0  AND  AGE >= 26.0  AND  GCSAMPT >= 1.0  THEN  usage = 192 : target = uncertainty groupPr(0) = 0.005208333333333333;Pr(1) = 0.9947916666666666;
# ELSE IF 0.0 <= ABDAMPT < 1.0  AND  GCS >= 15.0  AND  0.0 <= CHESTAMPT < 1.0  AND  0.0 <= HEADAMPT < 1.0  AND  7.1082 <= RTS < 7.8408  THEN  usage = 378 : target = uncertainty groupPr(0) = 0.9365079365079365;Pr(1) = 0.06349206349206349;
# ELSE IF 7.1082 <= RTS < 7.8408  AND  ABDAMPT >= 1.0  AND  0.0 <= GCSAMPT < 1.0  THEN  usage = 503 : target = uncertainty groupPr(0) = 0.20278330019880716;Pr(1) = 0.7972166998011928;
# ELSE IF 1.0 <= AMPT < 2.0  AND  HEADAMPT >= 1.0  AND  Mechanism >= 1.0  THEN  usage = 250 : target = uncertainty groupPr(0) = 0.208;Pr(1) = 0.792;
# ELSE IF HEADAMPT >= 1.0  AND  0.0 <= PhysiologicalAMPT < 1.0  AND  0.0 <= LEGAMPT < 1.0  AND  AGE < 47.0  AND  SI < 0.9219304079999999  THEN  usage = 1804 : target = uncertainty groupPr(0) = 0.7289356984478935;Pr(1) = 0.2710643015521064;
# ELSE IF Mechanism >= 1.0  AND  SIRANK < 2.0  AND  AGE >= 36.0  AND  0.0 <= SEX < 1.0  AND  0.0 <= ARMAMPT < 1.0  THEN  usage = 594 : target = uncertainty groupPr(0) = 0.24242424242424243;Pr(1) = 0.7575757575757576;
# ELSE IF RR >= 24.0  AND  LEGAMPT >= 1.0  AND  0.0 <= MultisystemAMPT < 1.0  AND  AgeGroups >= 4.0  THEN  usage = 272 : target = uncertainty groupPr(0) = 0.1801470588235294;Pr(1) = 0.8198529411764706;
# ELSE IF RR < 20.0  AND  ARMAMPT >= 1.0  AND  EDMOTOR < 6.0  AND  CHESTAMPT >= 1.0  AND  HEADAMPT >= 1.0  THEN  usage = 282 : target = uncertainty groupPr(0) = 0.8936170212765957;Pr(1) = 0.10638297872340426;
# ELSE IF GCSAMPT >= 1.0  AND  0.0 <= LEGAMPT < 1.0  AND  ABDAMPT >= 1.0  AND  0.0 <= CHESTAMPT < 1.0  AND  MultisystemAMPT >= 1.0  THEN  usage = 81 : target = uncertainty groupPr(0) = 0.037037037037037035;Pr(1) = 0.9629629629629629;
# ELSE IF 0.525316456 <= SI < 0.776978417  AND  GCS >= 15.0  AND  0.0 <= Mechanism < 1.0  AND  SEX >= 1.0  THEN  usage = 684 : target = uncertainty groupPr(0) = 0.6915204678362573;Pr(1) = 0.3084795321637427;
# ELSE IF GCS < 15.0  AND  SI < 0.687022901  THEN  usage = 681 : target = uncertainty groupPr(0) = 0.37298091042584436;Pr(1) = 0.6270190895741556;
# ELSE IF 0.0 <= ABDAMPT < 1.0  AND  RR < 20.0  AND  0.0 <= CHESTAMPT < 1.0  AND  AgeGroups < 5.0  THEN  usage = 648 : target = uncertainty groupPr(0) = 0.6666666666666666;Pr(1) = 0.3333333333333333;
# ELSE IF SI >= 0.9219304079999999  AND  0.0 <= HEADAMPT < 1.0  AND  CHESTAMPT >= 1.0  AND  GCS >= 13.0  THEN  usage = 297 : target = uncertainty groupPr(0) = 0.16498316498316498;Pr(1) = 0.835016835016835;
# ELSE IF 36.0 <= AGE < 61.0  AND  112.0 <= SYSBP < 156.0  THEN  usage = 1103 : target = uncertainty groupPr(0) = 0.5974614687216682;Pr(1) = 0.40253853127833183;
# ELSE IF LEGAMPT >= 1.0  AND  0.0 <= RTSCode < 1.0  AND  ABDAMPT >= 1.0  AND  0.0 <= CHESTAMPT < 1.0  AND  RR >= 20.0  THEN  usage = 85 : target = uncertainty groupPr(0) = 0.047058823529411764;Pr(1) = 0.9529411764705882;
# ELSE IF 1.0 <= AMPT < 2.0  AND  EDMOTOR < 6.0  THEN  usage = 147 : target = uncertainty groupPr(0) = 0.2925170068027211;Pr(1) = 0.7074829931972789;
#  ELSE  usage = 4085 : target = uncertainty groupPr(0) = 0.5022583559168925;Pr(1) = 0.4977416440831075;
# {'max_rules': inf, 'beam_width': 1, 'min_support': 1, 'max_depth': 5, 'alpha_gain': 0.6}
# /home/tntech.edu/kebrown46/RuleList/rulelist/datastructure/data.py:80: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for name, values in self.input_data.iteritems():
# /home/tntech.edu/kebrown46/RuleList/rulelist/rulelistmodel/categoricalmodel/categoricaltarget.py:40: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self.categories = {colname: colvals.unique() for colname, colvals in target_values.iteritems()} #ignores NANs values
# /home/tntech.edu/kebrown46/RuleList/rulelist/rulelistmodel/categoricalmodel/categoricaltarget.py:54: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for namecol, colvals in target_values.iteritems():
# Iteration: 1
# Iteration: 2
# Iteration: 3
# Iteration: 4
# Iteration: 5
# Iteration: 6
# Iteration: 7
# Iteration: 8
# Iteration: 9
# Iteration: 10
# Iteration: 11
# Iteration: 12
# Iteration: 13
# Iteration: 14
# Iteration: 15
# Iteration: 16
# Iteration: 17
# Iteration: 18
# Iteration: 19
# Iteration: 20
# Iteration: 21
# Iteration: 22
# Iteration: 23
# Iteration: 24
# Iteration: 25
# Iteration: 26
# Iteration: 27

# %%
print("DONE lol")
